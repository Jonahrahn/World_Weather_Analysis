# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import requests
from Config import weather_api_key

#URL setup
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 725

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city = "London"
city_url = url + "&q=" + city.replace(" ","+")  + '&units=imperial'
city_weather = requests.get(city_url).json()
print(city_weather["weather"][0]['description'])
# Out:
# overcast clouds

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")  + '&units=imperial'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | anchorage
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | karakol
# Processing Record 6 of Set 1 | sept-iles
# Processing Record 7 of Set 1 | khuzhir
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | souillac
# Processing Record 10 of Set 1 | marawi
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | ahumada
# City not found. Skipping...
# Processing Record 13 of Set 1 | tayu
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | auki
# Processing Record 17 of Set 1 | houston
# Processing Record 18 of Set 1 | inhambane
# Processing Record 19 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | oranjestad
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | sur
# Processing Record 28 of Set 1 | lianran
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | artigas
# Processing Record 31 of Set 1 | drumnadrochit
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | katsuura
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | ordynskoye
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | aranos
# Processing Record 39 of Set 1 | husavik
# Processing Record 40 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | quelimane
# Processing Record 43 of Set 1 | salalah
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | samfya
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | zuenoula
# Processing Record 50 of Set 1 | grindavik
# Processing Record 1 of Set 2 | lagoa
# Processing Record 2 of Set 2 | ambatofinandrahana
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | norden
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | arman
# Processing Record 8 of Set 2 | tiznit
# Processing Record 9 of Set 2 | iwanai
# Processing Record 10 of Set 2 | nyurba
# Processing Record 11 of Set 2 | oussouye
# Processing Record 12 of Set 2 | kralendijk
# Processing Record 13 of Set 2 | orlik
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | kudahuvadhoo
# Processing Record 19 of Set 2 | luz
# Processing Record 20 of Set 2 | nieuw amsterdam
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | gueret
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | hobyo
# Processing Record 25 of Set 2 | fallon
# Processing Record 26 of Set 2 | shelburne
# Processing Record 27 of Set 2 | muisne
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 2 | larap
# Processing Record 33 of Set 2 | constitucion
# Processing Record 34 of Set 2 | alugan
# Processing Record 35 of Set 2 | port shepstone
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | loding
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 2 | nusaybin
# Processing Record 41 of Set 2 | santiago de cao
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | rundu
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | sao filipe
# Processing Record 47 of Set 2 | ostersund
# Processing Record 48 of Set 2 | inongo
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | barahan
# Processing Record 1 of Set 3 | abu dhabi
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | yendi
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | konevo
# Processing Record 6 of Set 3 | labuan
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | chapada dos guimaraes
# Processing Record 9 of Set 3 | qasigiannguit
# Processing Record 10 of Set 3 | lorengau
# Processing Record 11 of Set 3 | bloemhof
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | altamira
# Processing Record 14 of Set 3 | lavrentiya
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | lerwick
# Processing Record 17 of Set 3 | ambilobe
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | naushki
# Processing Record 20 of Set 3 | tukrah
# Processing Record 21 of Set 3 | cowra
# Processing Record 22 of Set 3 | luanda
# Processing Record 23 of Set 3 | berlevag
# Processing Record 24 of Set 3 | bandarbeyla
# Processing Record 25 of Set 3 | rafaela
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | binzhou
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | omboue
# Processing Record 31 of Set 3 | sivaki
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | namtsy
# Processing Record 34 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 3 | komsomolskiy
# Processing Record 36 of Set 3 | mangan
# Processing Record 37 of Set 3 | rhyl
# Processing Record 38 of Set 3 | bubaque
# Processing Record 39 of Set 3 | bontang
# Processing Record 40 of Set 3 | aswan
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | kavaratti
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | saint-augustin
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | punta arenas
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 4 | altay
# Processing Record 2 of Set 4 | teguldet
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | los llanos de aridane
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | rock springs
# Processing Record 7 of Set 4 | garland
# Processing Record 8 of Set 4 | mangit
# Processing Record 9 of Set 4 | waddan
# Processing Record 10 of Set 4 | miklavz na dravskem polju
# Processing Record 11 of Set 4 | borger
# Processing Record 12 of Set 4 | aklavik
# Processing Record 13 of Set 4 | rorvik
# Processing Record 14 of Set 4 | turukhansk
# Processing Record 15 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | vaini
# Processing Record 18 of Set 4 | superior
# Processing Record 19 of Set 4 | manoel urbano
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | dunajska streda
# Processing Record 22 of Set 4 | gigmoto
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | hobart
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | busselton
# Processing Record 28 of Set 4 | hailar
# Processing Record 29 of Set 4 | krasnyy chikoy
# Processing Record 30 of Set 4 | severo-kurilsk
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | pokotylivka
# Processing Record 33 of Set 4 | tanshui
# City not found. Skipping...
# Processing Record 34 of Set 4 | barrow
# Processing Record 35 of Set 4 | gobabis
# Processing Record 36 of Set 4 | champerico
# Processing Record 37 of Set 4 | mahajanga
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | sola
# Processing Record 42 of Set 4 | vardo
# Processing Record 43 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | muroto
# Processing Record 47 of Set 4 | morgan city
# Processing Record 48 of Set 4 | ust-omchug
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | kaitangata
# Processing Record 2 of Set 5 | yellowknife
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | verkhoyansk
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | albion
# Processing Record 7 of Set 5 | atambua
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 5 | hirara
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | micheweni
# Processing Record 13 of Set 5 | narasannapeta
# Processing Record 14 of Set 5 | tura
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 5 | abu kamal
# Processing Record 18 of Set 5 | boende
# Processing Record 19 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 5 | the valley
# Processing Record 21 of Set 5 | voh
# Processing Record 22 of Set 5 | big spring
# Processing Record 23 of Set 5 | ayr
# Processing Record 24 of Set 5 | acarau
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | honiara
# Processing Record 28 of Set 5 | nizwa
# Processing Record 29 of Set 5 | bosaso
# Processing Record 30 of Set 5 | coihaique
# Processing Record 31 of Set 5 | xichang
# Processing Record 32 of Set 5 | asau
# Processing Record 33 of Set 5 | doha
# Processing Record 34 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 5 | springdale
# Processing Record 36 of Set 5 | asosa
# Processing Record 37 of Set 5 | glenwood springs
# Processing Record 38 of Set 5 | lensk
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | clyde river
# Processing Record 42 of Set 5 | zhangjiakou
# Processing Record 43 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | airai
# Processing Record 46 of Set 5 | nguruka
# Processing Record 47 of Set 5 | sonqor
# Processing Record 48 of Set 5 | mujiayingzi
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | lebu
# Processing Record 2 of Set 6 | koumac
# Processing Record 3 of Set 6 | labuhan
# Processing Record 4 of Set 6 | rockland
# Processing Record 5 of Set 6 | vidalia
# Processing Record 6 of Set 6 | lompoc
# Processing Record 7 of Set 6 | dimbokro
# Processing Record 8 of Set 6 | tunceli
# Processing Record 9 of Set 6 | shimoda
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | sechura
# Processing Record 12 of Set 6 | westport
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | meulaboh
# Processing Record 15 of Set 6 | svetlogorsk
# Processing Record 16 of Set 6 | brownsville
# Processing Record 17 of Set 6 | asfi
# Processing Record 18 of Set 6 | keita
# Processing Record 19 of Set 6 | pacific grove
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | jaumave
# Processing Record 22 of Set 6 | cairns
# Processing Record 23 of Set 6 | rio gallegos
# Processing Record 24 of Set 6 | nueve de julio
# Processing Record 25 of Set 6 | touba
# Processing Record 26 of Set 6 | kargasok
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | changzhou
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | zeya
# Processing Record 31 of Set 6 | matamoros
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | srednekolymsk
# Processing Record 34 of Set 6 | angoche
# Processing Record 35 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 6 | gwanda
# Processing Record 39 of Set 6 | belomorsk
# Processing Record 40 of Set 6 | pevek
# Processing Record 41 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 6 | port moresby
# Processing Record 43 of Set 6 | bengkulu
# Processing Record 44 of Set 6 | khani
# Processing Record 45 of Set 6 | ngunguru
# Processing Record 46 of Set 6 | jalu
# Processing Record 47 of Set 6 | chase
# Processing Record 48 of Set 6 | mount gambier
# Processing Record 49 of Set 6 | toamasina
# Processing Record 50 of Set 6 | ballina
# Processing Record 1 of Set 7 | caravelas
# Processing Record 2 of Set 7 | yining
# Processing Record 3 of Set 7 | sinnamary
# Processing Record 4 of Set 7 | thinadhoo
# Processing Record 5 of Set 7 | yenagoa
# Processing Record 6 of Set 7 | ko samui
# Processing Record 7 of Set 7 | salekhard
# Processing Record 8 of Set 7 | kamenka
# Processing Record 9 of Set 7 | jilib
# Processing Record 10 of Set 7 | alannay
# Processing Record 11 of Set 7 | bethanien
# Processing Record 12 of Set 7 | ahuimanu
# Processing Record 13 of Set 7 | aguimes
# Processing Record 14 of Set 7 | sakleshpur
# Processing Record 15 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 7 | faya
# Processing Record 17 of Set 7 | san pedro del parana
# Processing Record 18 of Set 7 | jauja
# Processing Record 19 of Set 7 | perbaungan
# Processing Record 20 of Set 7 | chino valley
# Processing Record 21 of Set 7 | chicama
# Processing Record 22 of Set 7 | amalapuram
# Processing Record 23 of Set 7 | morag
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 7 | rauma
# Processing Record 27 of Set 7 | klaksvik
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | san cristobal
# Processing Record 30 of Set 7 | changde
# Processing Record 31 of Set 7 | chokurdakh
# Processing Record 32 of Set 7 | alofi
# Processing Record 33 of Set 7 | anadyr
# Processing Record 34 of Set 7 | vila do maio
# Processing Record 35 of Set 7 | port hedland
# Processing Record 36 of Set 7 | kirakira
# Processing Record 37 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 7 | naro
# Processing Record 39 of Set 7 | tiksi
# Processing Record 40 of Set 7 | porto walter
# Processing Record 41 of Set 7 | devonport
# Processing Record 42 of Set 7 | rio grande
# Processing Record 43 of Set 7 | provideniya
# Processing Record 44 of Set 7 | conceicao do araguaia
# Processing Record 45 of Set 7 | emba
# Processing Record 46 of Set 7 | sabang
# Processing Record 47 of Set 7 | lata
# Processing Record 48 of Set 7 | espanola
# Processing Record 49 of Set 7 | tampere
# Processing Record 50 of Set 7 | madison
# Processing Record 1 of Set 8 | saltpond
# Processing Record 2 of Set 8 | erdenet
# Processing Record 3 of Set 8 | norman wells
# Processing Record 4 of Set 8 | boddam
# Processing Record 5 of Set 8 | sao joao da barra
# Processing Record 6 of Set 8 | jatiroto
# Processing Record 7 of Set 8 | touros
# Processing Record 8 of Set 8 | santa cruz
# Processing Record 9 of Set 8 | galle
# Processing Record 10 of Set 8 | novonikolayevskiy
# Processing Record 11 of Set 8 | belmonte
# Processing Record 12 of Set 8 | kailua
# Processing Record 13 of Set 8 | mantua
# Processing Record 14 of Set 8 | vila velha
# Processing Record 15 of Set 8 | west richland
# Processing Record 16 of Set 8 | mindelo
# Processing Record 17 of Set 8 | yamada
# Processing Record 18 of Set 8 | yukamenskoye
# Processing Record 19 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 8 | muniz freire
# Processing Record 21 of Set 8 | noumea
# Processing Record 22 of Set 8 | lubango
# Processing Record 23 of Set 8 | yerbogachen
# Processing Record 24 of Set 8 | rivadavia
# Processing Record 25 of Set 8 | vestmanna
# Processing Record 26 of Set 8 | mogadishu
# Processing Record 27 of Set 8 | itarema
# Processing Record 28 of Set 8 | oktyabrskoye
# Processing Record 29 of Set 8 | aykhal
# Processing Record 30 of Set 8 | chake chake
# Processing Record 31 of Set 8 | pindiga
# Processing Record 32 of Set 8 | kabalo
# Processing Record 33 of Set 8 | tomatlan
# Processing Record 34 of Set 8 | gazalkent
# Processing Record 35 of Set 8 | dongsheng
# Processing Record 36 of Set 8 | manokwari
# Processing Record 37 of Set 8 | quatre cocos
# Processing Record 38 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | eagle pass
# Processing Record 41 of Set 8 | guaratinga
# Processing Record 42 of Set 8 | pangnirtung
# Processing Record 43 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 8 | biak
# Processing Record 45 of Set 8 | clive
# Processing Record 46 of Set 8 | vung tau
# Processing Record 47 of Set 8 | scarborough
# Processing Record 48 of Set 8 | ahipara
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 50 of Set 8 | ambon
# Processing Record 1 of Set 9 | matongo
# Processing Record 2 of Set 9 | nador
# Processing Record 3 of Set 9 | douglas
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | shiyan
# Processing Record 6 of Set 9 | makat
# Processing Record 7 of Set 9 | inirida
# Processing Record 8 of Set 9 | curuguaty
# Processing Record 9 of Set 9 | marana
# Processing Record 10 of Set 9 | necochea
# Processing Record 11 of Set 9 | tabou
# Processing Record 12 of Set 9 | lucapa
# Processing Record 13 of Set 9 | rochegda
# Processing Record 14 of Set 9 | suez
# Processing Record 15 of Set 9 | dongying
# Processing Record 16 of Set 9 | pahrump
# Processing Record 17 of Set 9 | teahupoo
# Processing Record 18 of Set 9 | porto santo
# Processing Record 19 of Set 9 | marathon
# Processing Record 20 of Set 9 | tautira
# Processing Record 21 of Set 9 | vallenar
# Processing Record 22 of Set 9 | porto nacional
# Processing Record 23 of Set 9 | sitka
# Processing Record 24 of Set 9 | ewa beach
# Processing Record 25 of Set 9 | nuuk
# Processing Record 26 of Set 9 | kieta
# Processing Record 27 of Set 9 | kanniyakumari
# Processing Record 28 of Set 9 | ribeira grande
# Processing Record 29 of Set 9 | saint-louis
# Processing Record 30 of Set 9 | tahe
# Processing Record 31 of Set 9 | sinj
# Processing Record 32 of Set 9 | celestun
# Processing Record 33 of Set 9 | chokwe
# Processing Record 34 of Set 9 | haines junction
# Processing Record 35 of Set 9 | casas grandes
# Processing Record 36 of Set 9 | smoky lake
# Processing Record 37 of Set 9 | blackfoot
# Processing Record 38 of Set 9 | brigantine
# Processing Record 39 of Set 9 | kousseri
# Processing Record 40 of Set 9 | yar-sale
# Processing Record 41 of Set 9 | fushun
# Processing Record 42 of Set 9 | batagay
# Processing Record 43 of Set 9 | praia
# Processing Record 44 of Set 9 | san francisco
# Processing Record 45 of Set 9 | itaqui
# Processing Record 46 of Set 9 | pangkalanbuun
# Processing Record 47 of Set 9 | vad
# Processing Record 48 of Set 9 | gornyak
# Processing Record 49 of Set 9 | cristalina
# Processing Record 50 of Set 9 | lewisporte
# Processing Record 1 of Set 10 | bayan
# Processing Record 2 of Set 10 | akdepe
# Processing Record 3 of Set 10 | fayaoue
# Processing Record 4 of Set 10 | eureka
# Processing Record 5 of Set 10 | ariquemes
# Processing Record 6 of Set 10 | khuzdar
# Processing Record 7 of Set 10 | alyangula
# Processing Record 8 of Set 10 | ipora
# Processing Record 9 of Set 10 | gat
# Processing Record 10 of Set 10 | belaya gora
# Processing Record 11 of Set 10 | pyshma
# Processing Record 12 of Set 10 | kuminskiy
# Processing Record 13 of Set 10 | omsukchan
# Processing Record 14 of Set 10 | eggenstein-leopoldshafen
# Processing Record 15 of Set 10 | bathsheba
# Processing Record 16 of Set 10 | biltine
# Processing Record 17 of Set 10 | altamont
# Processing Record 18 of Set 10 | warmbad
# Processing Record 19 of Set 10 | fuente palmera
# Processing Record 20 of Set 10 | karratha
# Processing Record 21 of Set 10 | kalianget
# Processing Record 22 of Set 10 | george town
# Processing Record 23 of Set 10 | walvis bay
# Processing Record 24 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 10 | akyab
# Processing Record 26 of Set 10 | delitzsch
# Processing Record 27 of Set 10 | duluth
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 30 of Set 10 | buchanan
# Processing Record 31 of Set 10 | clifton
# Processing Record 32 of Set 10 | camalu
# Processing Record 33 of Set 10 | manggar
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | bowen
# Processing Record 36 of Set 10 | havre-saint-pierre
# Processing Record 37 of Set 10 | myitkyina
# Processing Record 38 of Set 10 | svetlyy
# Processing Record 39 of Set 10 | koungou
# Processing Record 40 of Set 10 | novikovo
# Processing Record 41 of Set 10 | port augusta
# Processing Record 42 of Set 10 | maniago
# Processing Record 43 of Set 10 | rawson
# Processing Record 44 of Set 10 | luderitz
# Processing Record 45 of Set 10 | moba
# Processing Record 46 of Set 10 | huarmey
# Processing Record 47 of Set 10 | coahuayana
# Processing Record 48 of Set 10 | talah
# City not found. Skipping...
# Processing Record 49 of Set 10 | goderich
# Processing Record 50 of Set 10 | prince rupert
# Processing Record 1 of Set 11 | yulara
# Processing Record 2 of Set 11 | koslan
# Processing Record 3 of Set 11 | urumqi
# Processing Record 4 of Set 11 | yarkovo
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | merauke
# Processing Record 7 of Set 11 | islamabad
# Processing Record 8 of Set 11 | lodja
# Processing Record 9 of Set 11 | dois vizinhos
# Processing Record 10 of Set 11 | kiruna
# Processing Record 11 of Set 11 | xining
# Processing Record 12 of Set 11 | taseyevo
# Processing Record 13 of Set 11 | kahului
# Processing Record 14 of Set 11 | sanmenxia
# Processing Record 15 of Set 11 | olga
# Processing Record 16 of Set 11 | bairiki
# Processing Record 17 of Set 11 | pita
# Processing Record 18 of Set 11 | san quintin
# Processing Record 19 of Set 11 | maceio
# Processing Record 20 of Set 11 | swiecie
# Processing Record 21 of Set 11 | neiafu
# Processing Record 22 of Set 11 | trofors
# Processing Record 23 of Set 11 | whitehorse
# Processing Record 24 of Set 11 | houffalize
# Processing Record 25 of Set 11 | demyanovo
# Processing Record 26 of Set 11 | puerto cabezas
# Processing Record 27 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 28 of Set 11 | koumra
# Processing Record 29 of Set 11 | pangoa
# Processing Record 30 of Set 11 | hualmay
# Processing Record 31 of Set 11 | puerto colombia
# Processing Record 32 of Set 11 | yarensk
# Processing Record 33 of Set 11 | chipiona
# Processing Record 34 of Set 11 | roald
# Processing Record 35 of Set 11 | marsh harbour
# Processing Record 36 of Set 11 | mitsamiouli
# Processing Record 37 of Set 11 | marzuq
# Processing Record 38 of Set 11 | thiruvananthapuram
# Processing Record 39 of Set 11 | iralaya
# Processing Record 40 of Set 11 | troitsko-pechorsk
# Processing Record 41 of Set 11 | ilhabela
# Processing Record 42 of Set 11 | broken hill
# Processing Record 43 of Set 11 | sapa
# Processing Record 44 of Set 11 | utica
# Processing Record 45 of Set 11 | portland
# Processing Record 46 of Set 11 | chifeng
# Processing Record 47 of Set 11 | winona
# Processing Record 48 of Set 11 | nouakchott
# Processing Record 49 of Set 11 | holguin
# Processing Record 50 of Set 11 | ostrovnoy
# Processing Record 1 of Set 12 | tomohon
# Processing Record 2 of Set 12 | barcelos
# Processing Record 3 of Set 12 | la ronge
# Processing Record 4 of Set 12 | vao
# Processing Record 5 of Set 12 | shache
# Processing Record 6 of Set 12 | lewisville
# Processing Record 7 of Set 12 | hambantota
# Processing Record 8 of Set 12 | mehamn
# Processing Record 9 of Set 12 | tarhunah
# City not found. Skipping...
# Processing Record 10 of Set 12 | qena
# Processing Record 11 of Set 12 | jurbarkas
# Processing Record 12 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 13 of Set 12 | cosala
# Processing Record 14 of Set 12 | tigil
# Processing Record 15 of Set 12 | mirnyy
# Processing Record 16 of Set 12 | obninsk
# Processing Record 17 of Set 12 | juneau
# Processing Record 18 of Set 12 | bud
# Processing Record 19 of Set 12 | acapulco
# Processing Record 20 of Set 12 | kanker
# Processing Record 21 of Set 12 | selenginsk
# Processing Record 22 of Set 12 | lasa
# Processing Record 23 of Set 12 | nipawin
# Processing Record 24 of Set 12 | goure
# Processing Record 25 of Set 12 | lumberton
# Processing Record 26 of Set 12 | banjar
# Processing Record 27 of Set 12 | mogok
# Processing Record 28 of Set 12 | dunedin
# Processing Record 29 of Set 12 | tuatapere
# Processing Record 30 of Set 12 | belfast
# Processing Record 31 of Set 12 | muros
# Processing Record 32 of Set 12 | kembe
# Processing Record 33 of Set 12 | kayanza
# Processing Record 34 of Set 12 | chernyshevskiy
# Processing Record 35 of Set 12 | zhaotong
# Processing Record 36 of Set 12 | sibolga
# Processing Record 37 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 12 | sobolevo
# Processing Record 39 of Set 12 | sambava
# Processing Record 40 of Set 12 | korla
# Processing Record 41 of Set 12 | arlit
# Processing Record 42 of Set 12 | milkovo
# Processing Record 43 of Set 12 | siemiatycze
# Processing Record 44 of Set 12 | alekseyevsk
# Processing Record 45 of Set 12 | ozernovskiy
# Processing Record 46 of Set 12 | nyimba
# Processing Record 47 of Set 12 | nanortalik
# Processing Record 48 of Set 12 | beska
# Processing Record 49 of Set 12 | taltal
# Processing Record 50 of Set 12 | mount isa
# Processing Record 1 of Set 13 | brae
# Processing Record 2 of Set 13 | ponta delgada
# Processing Record 3 of Set 13 | kamennogorsk
# Processing Record 4 of Set 13 | bonthe
# Processing Record 5 of Set 13 | grand gaube
# Processing Record 6 of Set 13 | keningau
# Processing Record 7 of Set 13 | fort madison
# Processing Record 8 of Set 13 | mumford
# Processing Record 9 of Set 13 | doume
# Processing Record 10 of Set 13 | voznesenye
# Processing Record 11 of Set 13 | marseille
# Processing Record 12 of Set 13 | niculitel
# Processing Record 13 of Set 13 | harnosand
# Processing Record 14 of Set 13 | axim
# Processing Record 15 of Set 13 | kamennomostskoye
# Processing Record 16 of Set 13 | shanhetun
# Processing Record 17 of Set 13 | venustiano carranza
# Processing Record 18 of Set 13 | abu zabad
# Processing Record 19 of Set 13 | wagar
# Processing Record 20 of Set 13 | lanxi
# Processing Record 21 of Set 13 | kutum
# Processing Record 22 of Set 13 | verkh-usugli
# Processing Record 23 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 13 | amuntai
# Processing Record 25 of Set 13 | alora
# Processing Record 26 of Set 13 | cooma
# Processing Record 27 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 13 | kenai
# Processing Record 29 of Set 13 | uruburetama
# Processing Record 30 of Set 13 | pittsburg
# Processing Record 31 of Set 13 | wau
# Processing Record 32 of Set 13 | taoudenni
# Processing Record 33 of Set 13 | chibuto
# Processing Record 34 of Set 13 | atar
# Processing Record 35 of Set 13 | qinhuangdao
# Processing Record 36 of Set 13 | raudeberg
# Processing Record 37 of Set 13 | suixi
# Processing Record 38 of Set 13 | saint anthony
# Processing Record 39 of Set 13 | gizo
# Processing Record 40 of Set 13 | chara
# Processing Record 41 of Set 13 | qandala
# Processing Record 42 of Set 13 | tabuk
# Processing Record 43 of Set 13 | kismayo
# Processing Record 44 of Set 13 | nishihara
# Processing Record 45 of Set 13 | margate
# Processing Record 46 of Set 13 | wasilla
# Processing Record 47 of Set 13 | fukue
# Processing Record 48 of Set 13 | hovd
# Processing Record 49 of Set 13 | uruacu
# Processing Record 50 of Set 13 | pitsunda
# Processing Record 1 of Set 14 | verkhnevilyuysk
# Processing Record 2 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 14 | chumikan
# Processing Record 4 of Set 14 | nemuro
# Processing Record 5 of Set 14 | ca mau
# Processing Record 6 of Set 14 | costa rica
# Processing Record 7 of Set 14 | funtua
# Processing Record 8 of Set 14 | ichihara
# Processing Record 9 of Set 14 | dahod
# Processing Record 10 of Set 14 | duzce
# Processing Record 11 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 12 of Set 14 | russell
# Processing Record 13 of Set 14 | laguna
# Processing Record 14 of Set 14 | mitchell
# Processing Record 15 of Set 14 | bima
# Processing Record 16 of Set 14 | muravlenko
# Processing Record 17 of Set 14 | ternate
# Processing Record 18 of Set 14 | vanimo
# Processing Record 19 of Set 14 | pimenta bueno
# Processing Record 20 of Set 14 | ligayan
# Processing Record 21 of Set 14 | oranjemund
# Processing Record 22 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 23 of Set 14 | kampene
# Processing Record 24 of Set 14 | tornio
# Processing Record 25 of Set 14 | baltesti
# City not found. Skipping...
# Processing Record 26 of Set 14 | naron
# Processing Record 27 of Set 14 | iskateley
# Processing Record 28 of Set 14 | unity
# Processing Record 29 of Set 14 | santa fe
# Processing Record 30 of Set 14 | nicolas bravo
# Processing Record 31 of Set 14 | banswada
# Processing Record 32 of Set 14 | starkville
# Processing Record 33 of Set 14 | douentza
# Processing Record 34 of Set 14 | tanete
# Processing Record 35 of Set 14 | okhotsk
# Processing Record 36 of Set 14 | baryshivka
# Processing Record 37 of Set 14 | camargo
# Processing Record 38 of Set 14 | boa vista
# Processing Record 39 of Set 14 | kenora
# Processing Record 40 of Set 14 | weligama
# Processing Record 41 of Set 14 | nouadhibou
# Processing Record 42 of Set 14 | kosonsoy
# Processing Record 43 of Set 14 | sokoni
# Processing Record 44 of Set 14 | america dourada
# Processing Record 45 of Set 14 | yarmouth
# Processing Record 46 of Set 14 | develi
# Processing Record 47 of Set 14 | shubarshi
# Processing Record 48 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 14 | pagudpud
# Processing Record 50 of Set 14 | kawardha
# Processing Record 1 of Set 15 | mattru
# Processing Record 2 of Set 15 | fort nelson
# Processing Record 3 of Set 15 | montepuez
# Processing Record 4 of Set 15 | san ignacio
# Processing Record 5 of Set 15 | imbituba
# Processing Record 6 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 7 of Set 15 | saleilua
# City not found. Skipping...
# Processing Record 8 of Set 15 | beira
# Processing Record 9 of Set 15 | chandia
# Processing Record 10 of Set 15 | poum
# Processing Record 11 of Set 15 | yablonovo
# Processing Record 12 of Set 15 | pirovskoye
# Processing Record 13 of Set 15 | buta
# Processing Record 14 of Set 15 | ruteng
# Processing Record 15 of Set 15 | diffa
# Processing Record 16 of Set 15 | taunggyi
# Processing Record 17 of Set 15 | mandeville
# Processing Record 18 of Set 15 | jacareacanga
# Processing Record 19 of Set 15 | saint-pierre
# Processing Record 20 of Set 15 | furstenfeld
# Processing Record 21 of Set 15 | ilovlya
# Processing Record 22 of Set 15 | mopti
# Processing Record 23 of Set 15 | dakar
# Processing Record 24 of Set 15 | forbes
# Processing Record 25 of Set 15 | emirdag
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Tuktoyaktuk  69.4541 -133.0374     -0.40        85          40
# 1        Ushuaia -54.8000  -68.3000     42.46        70          20
# 2      Anchorage  61.2181 -149.9003     15.93        87          90
# 3     Georgetown   5.4112  100.3354     78.89        93          20
# 4        Karakol  42.4907   78.3936     29.98        61         100
# ..           ...      ...       ...       ...       ...         ...
# 667      Ilovlya  49.3033   43.9796     25.90        85          11
# 668        Mopti  14.6667   -4.0000     79.83        25          10
# 669        Dakar  14.6937  -17.4441     80.73        89           0
# 670       Forbes -33.3833  148.0167     72.91        84         100
# 671      Emirdag  39.0197   31.1500     39.87        86           7
#
#      Wind Speed Country                 Date Weather Description
# 0         19.57      CA  2021-11-26 00:40:35    scattered clouds
# 1         21.85      AR  2021-11-26 00:37:12          few clouds
# 2          0.00      US  2021-11-26 00:40:36          light snow
# 3          1.01      MY  2021-11-26 00:40:36          few clouds
# 4          5.57      KG  2021-11-26 00:40:37     overcast clouds
# ..          ...     ...                  ...                 ...
# 667        5.55      RU  2021-11-26 01:01:56          few clouds
# 668        9.06      ML  2021-11-26 01:01:56           clear sky
# 669        0.00      SN  2021-11-26 00:57:25           clear sky
# 670        6.31      AU  2021-11-26 01:01:57          light rain
# 671        3.22      TR  2021-11-26 01:01:57           clear sky
#
# [672 rows x 10 columns]

# %%
new_column_order = ["City" , "Country" , "Date" , "Lat" , "Lng" , "Max Temp" , "Humidity" , "Cloudiness" , "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Tuktoyaktuk      CA  2021-11-26 00:40:35  69.4541 -133.0374     -0.40
# 1      Ushuaia      AR  2021-11-26 00:37:12 -54.8000  -68.3000     42.46
# 2    Anchorage      US  2021-11-26 00:40:36  61.2181 -149.9003     15.93
# 3   Georgetown      MY  2021-11-26 00:40:36   5.4112  100.3354     78.89
# 4      Karakol      KG  2021-11-26 00:40:37  42.4907   78.3936     29.98
# 5    Sept-Iles      CA  2021-11-26 00:37:49  50.2001  -66.3821     37.06
# 6      Khuzhir      RU  2021-11-26 00:40:38  53.1939  107.3397     26.92
# 7     Hermanus      ZA  2021-11-26 00:37:53 -34.4187   19.2345     62.80
# 8     Souillac      MU  2021-11-26 00:40:38 -20.5167   57.5167     73.78
# 9       Marawi      PH  2021-11-26 00:40:39   7.9986  124.2928     69.66
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        85          40       19.57    scattered clouds
# 1        70          20       21.85          few clouds
# 2        87          90        0.00          light snow
# 3        93          20        1.01          few clouds
# 4        61         100        5.57     overcast clouds
# 5        90          90        1.01                mist
# 6        76         100        6.55     overcast clouds
# 7        75           1       28.54           clear sky
# 8        88          40        3.44    scattered clouds
# 9        80         100        1.23     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
